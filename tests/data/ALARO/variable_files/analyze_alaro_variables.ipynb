# %% [markdown]
# # Analyze ALARO GRIB files
#
# This notebook reads all `.grb` files in the current directory and summarizes their contents (variables, units, etc.) into a table.

# %%
import xarray as xr
import pandas as pd
from pathlib import Path
import warnings
import urllib.request
import re

# Suppress warnings for cleaner output (optional)
warnings.filterwarnings('ignore')

# %%
def fetch_alaro_params(url):
    print(f"Fetching parameters from {url}...")
    try:
        with urllib.request.urlopen(url) as response:
            content = response.read().decode('utf-8')
        
        params = {}
        # The file seems to be formatted as ID:Abbrev:Description
        # We'll parse line by line.
        
        for line in content.splitlines():
            line = line.strip()
            if not line or line.startswith('#'):
                continue
            
            # Split by colon, limit to 2 splits (3 parts)
            parts = line.split(':', 2)
            
            if len(parts) >= 2:
                try:
                    pid = int(parts[0])
                    abbrev = parts[1].strip()
                    desc = parts[2].strip() if len(parts) > 2 else "N/A"
                    
                    # Store keyed by abbreviation (e.g. '10U', '2T', 'TotPrecip')
                    params[abbrev] = {
                        'id': pid,
                        'description': desc
                    }
                except ValueError:
                    # Skip lines where first part is not an int
                    continue
                    
        print(f"Loaded {len(params)} parameter definitions.")
        return params
    except Exception as e:
        print(f"Error fetching parameters: {e}")
        return {}

alaro_params_url = "https://opendata.meteo.be/resources/forecasts/alaro/params227-228.tab"
alaro_mapping = fetch_alaro_params(alaro_params_url)
# Out:
# Fetching parameters from https://opendata.meteo.be/resources/forecasts/alaro/params227-228.tab...
# Loaded 217 parameter definitions.

# %%
def analyze_grib_files(directory='.', param_mapping=None):
    path = Path(directory)
    # Ensure re is imported if not already, though it's better at top level
    import re
    
    grib_files = list(path.glob('*.grb'))
    
    results = []
    
    print(f"Found {len(grib_files)} .grb files.")
    
    for file_path in grib_files:
        
        # Parse variable tag from filename (e.g. alaro40l_2026012900_10U.grb -> 10U)
        # Using regex to find the last part separated by underscore before extension
        # pattern: ..._TAG.grb
        file_tag = "N/A"
        match = re.search(r'_([^_]+)$', file_path.stem)
        if match:
            file_tag = match.group(1)
            
        # Lookup expected data from mapping based on filename tag
        expected_desc = "N/A"
        expected_id = "N/A"
        
        if param_mapping and file_tag in param_mapping:
            entry = param_mapping[file_tag]
            expected_desc = entry['description']
            expected_id = entry['id']
            
        try:
            # Open dataset with cfgrib engine
            with xr.open_dataset(file_path, engine='cfgrib', indexpath='') as ds:
                
                # Iterate through data variables in the dataset
                for var_name, da in ds.data_vars.items():
                    
                    # Calculate mean value
                    try:
                        mean_val = float(da.mean().values)
                    except Exception:
                        mean_val = None

                    info = {
                        'file_name': file_path.name,
                        'file_tag': file_tag,
                        'expected_desc': expected_desc,
                        'expected_id': expected_id,
                        'variable_name': var_name,
                        'mean_value': mean_val,
                        'long_name': da.attrs.get('long_name', 'N/A'),
                        'units': da.attrs.get('units', 'N/A'),
                        'shape': da.shape,
                        'stepType': da.attrs.get('GRIB_stepType', 'N/A'),
                        'shortName': da.attrs.get('GRIB_shortName', 'N/A'),
                        'paramId': da.attrs.get('GRIB_paramId', 'N/A')
                    }
                    results.append(info)
                    
        except Exception as e:
            print(f"Error reading {file_path.name}: {e}")
            results.append({
                'file_name': file_path.name,
                'file_tag': file_tag,
                'expected_desc': expected_desc,
                'expected_id': expected_id,
                'variable_name': 'ERROR',
                'long_name': str(e)
            })
            
    # Reorder columns
    df = pd.DataFrame(results)
    if not df.empty and 'expected_desc' in df.columns:
        cols = ['file_name', 'file_tag', 'expected_desc', 'variable_name', 'long_name', 'mean_value', 'units', 'expected_id', 'paramId']
        # Add remaining columns
        cols += [c for c in df.columns if c not in cols]
        df = df[cols]
        
    return df

# %%
# Run the analysis with the mapping
df = analyze_grib_files('.', param_mapping=alaro_mapping)

# Display the table
display(df)
# Out:
# Found 34 .grb files.
# Error reading alaro40l_2026012900_R.grb: multiple values for unique key, try re-open the file with one of:
#     filter_by_keys={'typeOfLevel': 'heightAboveGround'}
#     filter_by_keys={'typeOfLevel': 'isobaricInhPa'}
#                             file_name   file_tag  \
# 0         alaro40l_2026012900_10U.grb        10U
# 1         alaro40l_2026012900_10V.grb        10V
# 2          alaro40l_2026012900_2D.grb         2D
# 3          alaro40l_2026012900_2T.grb         2T
# 4          alaro40l_2026012900_CR.grb         CR
# 5          alaro40l_2026012900_CS.grb         CS
# 6        alaro40l_2026012900_fzht.grb       fzht
# 7       alaro40l_2026012900_IFCCC.grb      IFCCC
# 8       alaro40l_2026012900_IFHCC.grb      IFHCC
# 9       alaro40l_2026012900_IFLCC.grb      IFLCC
# 10      alaro40l_2026012900_IFMCC.grb      IFMCC
# 11      alaro40l_2026012900_IFTCC.grb      IFTCC
# 12        alaro40l_2026012900_LSR.grb        LSR
# 13        alaro40l_2026012900_LSS.grb        LSS
# 14      alaro40l_2026012900_MaxT2.grb      MaxT2
# 15    alaro40l_2026012900_MerGust.grb    MerGust
# 16      alaro40l_2026012900_MinT2.grb      MinT2
# 17       alaro40l_2026012900_MSLP.grb       MSLP
# 18        alaro40l_2026012900_ORO.grb        ORO
# 19          alaro40l_2026012900_Q.grb          Q
# 20          alaro40l_2026012900_R.grb          R
# 21       alaro40l_2026012900_RH2M.grb       RH2M
# 22         alaro40l_2026012900_ST.grb         ST
# 23   alaro40l_2026012900_SurfCape.grb   SurfCape
# 24  alaro40l_2026012900_SurfLWrad.grb  SurfLWrad
# 25  alaro40l_2026012900_SurfSWrad.grb  SurfSWrad
# 26          alaro40l_2026012900_T.grb          T
# 27  alaro40l_2026012900_TotPrecip.grb  TotPrecip
# 28          alaro40l_2026012900_U.grb          U
# 29          alaro40l_2026012900_V.grb          V
# 30          alaro40l_2026012900_W.grb          W
# 31       alaro40l_2026012900_WBPT.grb       WBPT
# 32          alaro40l_2026012900_Z.grb          Z
# 33    alaro40l_2026012900_ZonGust.grb    ZonGust
#
#                         expected_desc variable_name  \
# 0    10 m u  wind component [m s**-1]       unknown
# 1    10 m v  wind component [m s**-1]       unknown
# 2   2 m dewpoint temperature [K or C]       unknown
# 3            2 m temperature [K or C]       unknown
# 4                 Convective rain [m]         strdc
# 5                 Convective snow [m]          u10n
# 6                  freezing level [m]       unknown
# 7       Inst flx Conv Cld Cover [0-1]       unknown
# 8       Inst flx High Cld Cover [0-1]          fzra
# 9        Inst flx Low Cld Cover [0-1]       unknown
# 10    Inst flx Medium Cld Cover [0-1]       unknown
# 11       Inst flx Tot Cld cover [0-1]         ilspf
# 12               Large scale rain [m]       unknown
# 13               Large scale snow [m]         ssrdc
# 14  2 m Max temp (since ppp) [K or C]       unknown
# 15               SBL Meridian gust []       unknown
# 16  2 m Min temp (since ppp) [K or C]       unknown
# 17       Mean sea level pressure [Pa]          swi2
# 18   Surface orography [m**2 s**-2 m]           cin
# 19      Specific humidity [kg kg**-1]       unknown
# 20              Relative humidity [%]         ERROR
# 21           2m Relative humidity [%]       unknown
# 22       Surface Temperature [K or C]       unknown
# 23                   Surface CAPE [J]          v200
# 24   Surf Thermal radiation [J m**-2]       unknown
# 25     Surf Solar radiation [J m**-2]       unknown
# 26               Temperature [K or C]       unknown
# 27            Total precipitation [m]          v10n
# 28               U-velocity [m s**-1]       unknown
# 29               V-velocity [m s**-1]       unknown
# 30       Vertical velocity [Pa s**-1]          ceil
# 31     Wet Bulb Poten Temper [K or C]       unknown
# 32          Geopotential [m**2 s**-2]       unknown
# 33                  SBL Zonal gust []       unknown
#
#                                             long_name    mean_value  \
# 0                                             unknown -1.755157e+00
# 1                                             unknown  2.711944e+00
# 2                                             unknown  2.754382e+02
# 3                                             unknown  2.763112e+02
# 4   Surface long-wave (thermal) radiation downward...  4.499003e-04
# 5                10 metre u-component of neutral wind  6.326314e-05
# 6                                             unknown  8.484856e+02
# 7                                             unknown  1.610348e-01
# 8                           Accumulated freezing rain  3.494167e-01
# 9                                             unknown  8.192638e-01
# 10                                            unknown  4.854639e-01
# 11   Instantaneous large-scale precipitation fraction  8.968225e-01
# 12                                            unknown  1.801959e-03
# 13  Surface short-wave (solar) radiation downward ...  8.627495e-04
# 14                                            unknown  2.764364e+02
# 15                                            unknown  5.259163e+00
# 16                                            unknown  2.761263e+02
# 17                      Soil wetness index in layer 2  9.982403e+04
# 18                              Convective inhibition  1.406830e+03
# 19                                            unknown  2.149913e-03
# 20  multiple values for unique key, try re-open th...           NaN
# 21                                            unknown  9.414201e+01
# 22                                            unknown  2.765551e+02
# 23                         200 metre V wind component  1.236496e+01
# 24                                            unknown -2.468758e+06
# 25                                            unknown  3.419302e+06
# 26                                            unknown  2.569467e+02
# 27               10 metre v-component of neutral wind  3.177925e-03
# 28                                            unknown  2.967152e+00
# 29                                            unknown  4.866797e+00
# 30                                            Ceiling  2.685852e-03
# 31                                            unknown  2.785840e+02
# 32                                            unknown  4.096903e+04
# 33                                            unknown -3.121266e+00
#
#             units  expected_id   paramId               shape stepType  \
# 0         unknown          192       0.0      (61, 177, 177)  instant
# 1         unknown          193       0.0      (61, 177, 177)  instant
# 2         unknown          195       0.0      (61, 177, 177)  instant
# 3         unknown          194       0.0      (61, 177, 177)  instant
# 4         J m**-2          130  228130.0      (61, 177, 177)  instant
# 5         m s**-1          131  228131.0      (61, 177, 177)  instant
# 6         unknown          234       0.0      (61, 177, 177)  instant
# 7         unknown          213       0.0      (61, 177, 177)  instant
# 8               m          216  228216.0      (61, 177, 177)  instant
# 9         unknown          214       0.0      (61, 177, 177)  instant
# 10        unknown          215       0.0      (61, 177, 177)  instant
# 11     Proportion          217  228217.0      (61, 177, 177)  instant
# 12        unknown          128       0.0      (61, 177, 177)  instant
# 13        J m**-2          129  228129.0      (61, 177, 177)  instant
# 14        unknown          198       0.0      (61, 177, 177)  instant
# 15        unknown          236       0.0      (61, 177, 177)  instant
# 16        unknown          199       0.0      (61, 177, 177)  instant
# 17  dimensionless           41  228041.0      (61, 177, 177)  instant
# 18       J kg**-1            1  228001.0      (61, 177, 177)  instant
# 19        unknown          105       0.0  (61, 15, 177, 177)  instant
# 20            NaN          106       NaN                 NaN      NaN
# 21        unknown          196       0.0      (61, 177, 177)  instant
# 22        unknown          200       0.0      (61, 177, 177)  instant
# 23        m s**-1          240  228240.0      (61, 177, 177)  instant
# 24        unknown          151       0.0      (60, 177, 177)  instant
# 25        unknown          150       0.0      (60, 177, 177)  instant
# 26        unknown           98       0.0  (61, 15, 177, 177)  instant
# 27        m s**-1          132  228132.0      (61, 177, 177)  instant
# 28        unknown          107       0.0  (61, 15, 177, 177)  instant
# 29        unknown          108       0.0  (61, 15, 177, 177)  instant
# 30              m          109  260109.0  (61, 15, 177, 177)  instant
# 31        unknown          102       0.0   (61, 3, 177, 177)  instant
# 32        unknown           96       0.0  (61, 15, 177, 177)  instant
# 33        unknown          235       0.0      (61, 177, 177)  instant
#
#    shortName
# 0    unknown
# 1    unknown
# 2    unknown
# 3    unknown
# 4      strdc
# 5       u10n
# 6    unknown
# 7    unknown
# 8       fzra
# 9    unknown
# 10   unknown
# 11     ilspf
# 12   unknown
# 13     ssrdc
# 14   unknown
# 15   unknown
# 16   unknown
# 17      swi2
# 18       cin
# 19   unknown
# 20       NaN
# 21   unknown
# 22   unknown
# 23      200v
# 24   unknown
# 25   unknown
# 26   unknown
# 27      v10n
# 28   unknown
# 29   unknown
# 30      ceil
# 31   unknown
# 32   unknown
# 33   unknown

# %%
# Export to CSV if needed
# df.to_csv('alaro_variables_summary.csv', index=False)
